# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# %%
data1 = pd.read_excel("frank hertz data.xlsx",sheet_name = "U1_1,44_U3_2,66_T_160",names = ["time","volt","volt2","current_na_160","acc_volt_160","freq","nothing"])
volt_data_1 =data1["acc_volt_160"]
amper_data_1 = data1["current_na_160"]
U1_1__44_U3_2__66_T_160_volt = volt_data_1.tolist()
U1_1__44_U3_2__66_T_160_amper = amper_data_1.tolist()

data2 = pd.read_excel("frank hertz data.xlsx",sheet_name = "u1-1,45-u3-2,66-T180",names = ["time","volt","volt2","current_na_180","acc_volt_180","freq","nothing"]) 
volt_data_2 =data2["acc_volt_180"]
amper_data_2 = data2["current_na_180"]
u1_1__45_u3_2__66_T_180_volt = volt_data_2.tolist()
u1_1__45_u3_2__66_T_180_amper = amper_data_2.tolist()


data3 = pd.read_excel("frank hertz data.xlsx",sheet_name = "u1-1,61-u3-2,66-T178",names = ["time","volt","volt2","current_na_178","acc_volt_178","freq","nothing"]) 
volt_data_3 =data3["acc_volt_178"]
amper_data_3 = data3["current_na_178"]
u1_1__61_u3_2__66_T_178_volt = volt_data_3.tolist()
u1_1__61_u3_2__66_T_178_amper = amper_data_3.tolist()


data4 = pd.read_excel("frank hertz data.xlsx",sheet_name = "u1-1,62-u3-2,66-T161",names = ["time","volt","volt2","current_na_161","acc_volt_161","freq"]) 
volt_data_4 =data4["acc_volt_161"]
amper_data_4 = data4["current_na_161"]
u1_1__61_u3_2__66_T_161_volt = volt_data_4.tolist()
u1_1__61_u3_2__66_T_161_amper = amper_data_4.tolist()


data5 = pd.read_excel("frank hertz data.xlsx",sheet_name = "u1-1,76-u3-2.67-T,191",names = ["time","volt","volt2","current_na_191","acc_volt_191","freq"]) 
volt_data_5 =data5["acc_volt_191"]
amper_data_5 = data5["current_na_191"]
u1_1__76_u3_2__67_T_191_volt = volt_data_5.tolist()
u1_1__76_u3_2__67_T_191_amper = amper_data_5.tolist()


data6 = pd.read_excel("frank hertz data.xlsx",sheet_name = "u1-1.41-u3-2.67-T171",names = ["time","volt","volt2","current_na_171","acc_volt_171","freq"]) 
volt_data_6 =data6["acc_volt_171"]
amper_data_6 = data6["current_na_171"]
u1_1__41_u3_2__67_T_171_volt = volt_data_6.tolist()
u1_1__41_u3_2__67_T_171_amper = amper_data_6.tolist()

data7 = pd.read_excel("frank hertz data.xlsx",sheet_name = "u1-1.62-u3-2.65-T169",names = ["time","volt","volt2","current_na_169","acc_volt_169","freq"]) 
volt_data_7 =data7["acc_volt_169"]
amper_data_7 = data7["current_na_169"]
u1_1__62_u3_2__65_T_169_volt = volt_data_7.tolist()
u1_1__62_u3_2__65_T_169_amper = amper_data_7.tolist()

data8 = pd.read_excel("frank hertz data.xlsx",sheet_name = "u1-2,04-u3-2.66-T191",names = ["time","volt","volt2","current_na_191","acc_volt_191","freq"]) 
volt_data_8 =data8["acc_volt_191"]
amper_data_8 = data8["current_na_191"]
u1_2__04_u3_2__66_T_191_volt = volt_data_8.tolist()
u1_2__04_u3_2__66_T_191_amper = amper_data_8.tolist()

# %%
# data T = 160
ax = plt.subplot()
plt.plot(U1_1__44_U3_2__66_T_160_volt,U1_1__44_U3_2__66_T_160_amper,label = "U1_1__44_U3_2__66_T_160")
plt.scatter(U1_1__44_U3_2__66_T_160_volt,U1_1__44_U3_2__66_T_160_amper,color = "red",label = "data points")
plt.xlabel("voltage V")
plt.ylabel("current nA")
plt.grid()
ax.legend()
plt.title("160 degrees celcius acc.voltage V vs. current in nano amperes")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0.5, 1.0, '160 degrees celcius acc.voltage V vs. current in nano amperes')

# %%
#data T = 180
ax2 = plt.subplot()
plt.plot(u1_1__45_u3_2__66_T_180_volt,u1_1__45_u3_2__66_T_180_amper,label = "u1_1__45_u3_2__66_T_180")
plt.scatter(u1_1__45_u3_2__66_T_180_volt,u1_1__45_u3_2__66_T_180_amper,color = "red",label = "data points")
plt.xlabel("voltage V")
plt.ylabel("current nA")
plt.grid()
ax2.legend()
plt.title("180 degrees celcius acc.voltage V vs. current in nano amperes")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0.5, 1.0, '180 degrees celcius acc.voltage V vs. current in nano amperes')

# %%
#data T = 178
ax3 = plt.subplot()
plt.plot(u1_1__61_u3_2__66_T_178_volt,u1_1__61_u3_2__66_T_178_amper,label = "u1_1__61_u3_2__66_T_178")
plt.scatter(u1_1__61_u3_2__66_T_178_volt,u1_1__61_u3_2__66_T_178_amper,color = "red",label = "data points")
plt.xlabel("voltage V")
plt.ylabel("current nA")
plt.grid()
ax3.legend()
plt.title("178 degrees celcius acc.voltage V vs. current in nano amperes")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0.5, 1.0, '178 degrees celcius acc.voltage V vs. current in nano amperes')

# %%
#data T = 161
ax4 = plt.subplot()
plt.plot(u1_1__61_u3_2__66_T_161_volt,u1_1__61_u3_2__66_T_161_amper,label = "u1_1__61_u3_2__66_T_161")
plt.scatter(u1_1__61_u3_2__66_T_161_volt,u1_1__61_u3_2__66_T_161_amper,color = "red",label = "data points")
plt.xlabel("voltage V")
plt.ylabel("current nA")
plt.grid()
ax4.legend()
plt.title("161 degrees celcius acc.voltage V vs. current in nano amperes")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0.5, 1.0, '161 degrees celcius acc.voltage V vs. current in nano amperes')

# %%
#data T = 191
ax5 = plt.subplot()
plt.plot(u1_1__76_u3_2__67_T_191_volt,u1_1__76_u3_2__67_T_191_amper,label = "u1_1__76_u3_2__67_T_191")
plt.scatter(u1_1__76_u3_2__67_T_191_volt,u1_1__76_u3_2__67_T_191_amper,color = "red",label = "data points")
plt.xlabel("voltage V")
plt.ylabel("current nA")
plt.grid()
ax5.legend()
plt.title("191 degrees celcius acc.voltage V vs. current in nano amperes")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0.5, 1.0, '191 degrees celcius acc.voltage V vs. current in nano amperes')

# %%
#data T = 171
ax6 = plt.subplot()
plt.plot(u1_1__41_u3_2__67_T_171_volt,u1_1__41_u3_2__67_T_171_amper,label = "u1_1__41_u3_2__67_T_171")
plt.scatter(u1_1__41_u3_2__67_T_171_volt,u1_1__41_u3_2__67_T_171_amper,color = "red",label = "data points")
plt.xlabel("voltage V")
plt.ylabel("current nA")
plt.grid()
ax6.legend()
plt.title("171 degrees celcius acc.voltage V vs. current in nano amperes")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0.5, 1.0, '171 degrees celcius acc.voltage V vs. current in nano amperes')

# %%
#data T = 169
ax7 = plt.subplot()
plt.plot(u1_1__62_u3_2__65_T_169_volt,u1_1__62_u3_2__65_T_169_amper,label = "u1_1__62_u3_2__65_T_169")
plt.scatter(u1_1__62_u3_2__65_T_169_volt,u1_1__62_u3_2__65_T_169_amper,color = "red",label = "data points")
plt.xlabel("voltage V")
plt.ylabel("current nA")
plt.grid()
ax7.legend()
plt.title("169 degrees celcius acc.voltage V vs. current in nano amperes")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0.5, 1.0, '169 degrees celcius acc.voltage V vs. current in nano amperes')

# %%
#data T = 191
ax8 = plt.subplot()
plt.plot(u1_2__04_u3_2__66_T_191_volt,u1_2__04_u3_2__66_T_191_amper,label = "u1_2__04_u3_2__66_T_191")
plt.scatter(u1_2__04_u3_2__66_T_191_volt,u1_2__04_u3_2__66_T_191_amper,color = "red",label = "data points")
plt.xlabel("voltage V")
plt.ylabel("current nA")
plt.grid()
ax8.legend()
plt.title("191 degrees celcius acc.voltage V vs. current in nano amperes")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0.5, 1.0, '191 degrees celcius acc.voltage V vs. current in nano amperes')

# %%
peaks_U1_1__44_U3_2__66_T_160_volt = [9.9,14.9,20.0,25.3]
peaks_U1_1__44_U3_2__66_T_160_amper = [0.9,1.2,1.5,1.8]

peaks_u1_1__45_u3_2__66_T_180_volt = [9.9,14.9,19.9,25.0]
peaks_u1_1__45_u3_2__66_T_180_amper = [0.16,0.38,0.8,1.0]

peaks_u1_1__61_u3_2__66_T_178_volt =[9.9,14.7,19.9,25.0]
peaks_u1_1__61_u3_2__66_T_178_amper =[0.7,1.0,1.2,1.5]

peaks_u1_1__61_u3_2__66_T_161_volt = [9.8,15.1,20.2,25.7]
peaks_u1_1__61_u3_2__66_T_161_amper = [1.3,2.1,3.0,4.2]

peaks_u1_1__76_u3_2__67_T_191_volt = [9.7,14.7,19.7,24.9]
peaks_u1_1__76_u3_2__67_T_191_amper = [0.9,1.3,1.8,2.3]

peaks_u1_1__41_u3_2__67_T_171_volt = [10.0,14.9,20.2,25.7]
peaks_u1_1__41_u3_2__67_T_171_amper = [0.88,1.3,1.7,2.3]

peaks_u1_1__62_u3_2__65_T_169_volt = [9.8,15.0,20.3,26.0]
peaks_u1_1__62_u3_2__65_T_169_amper= [1.9,2.5,3.3,4.3]

peaks_u1_2__04_u3_2__66_T_191_volt = [9.7,14.4,19.4,24.1]
peaks_u1_2__04_u3_2__66_T_191_amper = [0.3,0.7,1.3,1.9]
t_160 = []
t_180 = []
t_178 = []
t_161 = []
t_191_u = []
t_171 = []
t_169 = []
t_191 = []


mean_t_160 =[]
mean_t_180 =[]
mean_t_178 =[]
mean_t_161 =[]
mean_t_191_u =[]
mean_t_171 =[]
mean_t_169 =[]
mean_t_191 =[]

std_t_160 =[]
std_t_180 =[]
std_t_178 =[]
std_t_161 =[]
std_t_191_u =[]
std_t_171 =[]
std_t_169 =[]
std_t_191 =[]





peaks_volt_main = [peaks_U1_1__44_U3_2__66_T_160_volt,peaks_u1_1__45_u3_2__66_T_180_volt,peaks_u1_1__61_u3_2__66_T_178_volt,peaks_u1_1__61_u3_2__66_T_161_volt,peaks_u1_1__76_u3_2__67_T_191_volt,peaks_u1_1__41_u3_2__67_T_171_volt,peaks_u1_1__62_u3_2__65_T_169_volt,peaks_u1_2__04_u3_2__66_T_191_volt]

differences_main = [t_160,t_180,t_178,t_161,t_191_u,t_171,t_169,t_191]


mean_main = [mean_t_160,mean_t_180,mean_t_178,mean_t_161,mean_t_191_u,mean_t_171,mean_t_169,mean_t_191]
std_main = [std_t_160,std_t_180,std_t_178,std_t_161,std_t_191_u,std_t_171,std_t_169,std_t_191]

# %%
for k in range(len(peaks_volt_main)):
    for i in range(len(peaks_volt_main[k])-1):
        a = peaks_volt_main[k][i+1] - peaks_volt_main[k][i]
        differences_main[k].append(a)
        
        
for i in range(len(mean_main)):
    mean_main[i] = np.mean(differences_main[i])
    std_main[i] = np.std(differences_main[i])

# %%
def Weighted_average(values,stds):
    a = np.array(values)
    b = (np.array(stds))**2
    üst = np.sum(a/b)
    alt = np.sum(1/b)
    
    mean_average = üst/alt
    print(mean_average)
    return mean_average
    
def uncertainty(uncer):
    err = np.array(std_main)
    
    total_un = np.sqrt(np.sum(err**2))
    print(total_un)
    return total_un

# %%
print("weighted average : ", Weighted_average(mean_main,std_main))
print("uncertainty : ", uncertainty(std_main))
# Out:
# 5.058235807860262
# weighted average :  5.058235807860262
# 0.4594682917363403
# uncertainty :  0.4594682917363403

# %%
 X_square = ((5.05 - 4.9)/0.4)**2
# Out:
# 0.140624999999999
